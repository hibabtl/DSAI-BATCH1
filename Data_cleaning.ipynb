# %% [markdown]
# <a href="https://colab.research.google.com/github/hibabtl/DSAI-SVM-CODE/blob/main/Data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/titanic_data.csv")

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.drop(columns=['Name','Ticket','Fare','Cabin'])
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0              1         0       3    male  22.0      1      0        S
# 1              2         1       1  female  38.0      1      0        C
# 2              3         1       3  female  26.0      0      0        S
# 3              4         1       1  female  35.0      1      0        S
# 4              5         0       3    male  35.0      0      0        S
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0        S
# 887          888         1       1  female  19.0      0      0        S
# 888          889         0       3  female   NaN      1      2        S
# 889          890         1       1    male  26.0      0      0        C
# 890          891         0       3    male  32.0      0      0        Q
#
# [891 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Embarked     889 non-null    object
# dtypes: float64(1), int64(5), object(2)
# memory usage: 55.8+ KB

# %% [markdown]
# ## **CONVERTING CATEGORICAL DATA INTO NUMERIC DATA**

# %%
#df['Sex']=df['Sex'].apply(lambda x:1 if x=='male' else 0)
#df['Sex']

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df['Sex']=df['Sex'].apply(lambda x:1 if x=='male' else 0)
df['Sex']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %% [markdown]
# # **DEALING WITH NULL VALUES**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# dtype: int64

# %%
int(df['Age'].mean())
# Out:
# 29

# %%
df['Age']=df['Age'].fillna(np.mean(df['Age']))
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Embarked       2
# dtype: int64

# %%
df['Embarked']=df['Embarked'].dropna()

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Embarked       2
# dtype: int64

# %%
len(df)
# Out:
# 891

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch Embarked
# 0              1         0       3    1  22.000000      1      0        S
# 1              2         1       1    0  38.000000      1      0        C
# 2              3         1       3    0  26.000000      0      0        S
# 3              4         1       1    0  35.000000      1      0        S
# 4              5         0       3    1  35.000000      0      0        S
# ..           ...       ...     ...  ...        ...    ...    ...      ...
# 886          887         0       2    1  27.000000      0      0        S
# 887          888         1       1    0  19.000000      0      0        S
# 888          889         0       3    0  29.699118      1      2        S
# 889          890         1       1    1  26.000000      0      0        C
# 890          891         0       3    1  32.000000      0      0        Q
#
# [889 rows x 8 columns]
